# %%
#import Pandas Library
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Assigned dataset variable to read 50_Startups.csv file with the function of read_csv
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#Convert Categorical data to nominal data (one hot encoding) and drop first categorical (sex_male, smoker_yes)
dataset=pd.get_dummies(dataset,dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
#Find column Headers
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
#Assign variable (independent) for only input data
independent=dataset[['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
#Assign variable for Output (dependent)
dependent=dataset['charges']

# %%
dependent
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {
    "kernel":["rbf", "poly", "sigmoid", "linear"],
    "C":[10,100,1000,2000,3000],
    "gamma":["scale"]
}
grid = GridSearchCV(SVR(), param_grid, cv=3, scoring="r2", verbose=3, n_jobs=-1)
#fitting the model for grid search
grid.fit(independent, dependent)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# GridSearchCV(cv=3, estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000], 'gamma': ['scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              scoring='r2', verbose=3)

# %%
#print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
print ("The R_Score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_Score value for best parameter {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.097025      0.004424         0.096127        0.005967       10
# 1        0.075951      0.001812         0.027267        0.000460       10
# 2        0.103252      0.002916         0.037891        0.001035       10
# 3        0.019921      0.017656         0.004490        0.000539       10
# 4        0.098440      0.003481         0.099435        0.001022      100
# 5        0.076515      0.003161         0.028563        0.001270      100
# 6        0.101763      0.002904         0.037275        0.000903      100
# 7        0.020539      0.019664         0.004957        0.001126      100
# 8        0.138312      0.001523         0.091082        0.005798     1000
# 9        0.102775      0.000717         0.027333        0.000401     1000
# 10       0.083995      0.018002         0.031721        0.007899     1000
# 11       0.018246      0.018917         0.003434        0.000396     1000
# ...

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male <0 or 1>:"))
sex_female_input=int(input("Sex Female <0 or 1>:"))
smoker_yes_input=int(input("Smoker Yes <0 or 1>:"))
# Out:
# Age: 35
# BMI: 43
# Children: 2
# Sex Male <0 or 1>: 1
# Sex Female <0 or 1>: 1
# Smoker Yes <0 or 1>: 1

# %%
Future_Prediction = grid.predict([[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input, sex_female_input]])
print("Future_Prediction={}".format(Future_Prediction))
print("Best Parameters:", grid.best_params_)
print("Best Score:", grid.best_score_)
# Out:
# Future_Prediction=[1.11181231]
# Best Parameters: {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
# Best Score: 0.9999999999578332
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
